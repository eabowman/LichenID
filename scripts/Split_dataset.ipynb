# %%
# Split the dataset into val and train

# %%
import os
import random
import shutil

def split_dataset(base_dir, output_dir, train_split=0.8):
    random.seed(42)  # for reproducibility

    # Make output directories
    train_dir = os.path.join(output_dir, 'train')
    val_dir = os.path.join(output_dir, 'val')
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(val_dir, exist_ok=True)

    # For each class folder
    classes = [d for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d))]
    for cls in classes:
        class_dir = os.path.join(base_dir, cls)
        images = [f for f in os.listdir(class_dir) if os.path.isfile(os.path.join(class_dir, f))]
        random.shuffle(images)

        split_idx = int(len(images) * train_split)
        train_images = images[:split_idx]
        val_images = images[split_idx:]

        # Create class folders in train and val
        os.makedirs(os.path.join(train_dir, cls), exist_ok=True)
        os.makedirs(os.path.join(val_dir, cls), exist_ok=True)

        # Copy images
        for img in train_images:
            src = os.path.join(class_dir, img)
            dst = os.path.join(train_dir, cls, img)
            shutil.copy2(src, dst)

        for img in val_images:
            src = os.path.join(class_dir, img)
            dst = os.path.join(val_dir, cls, img)
            shutil.copy2(src, dst)

        print(f"Class '{cls}': {len(train_images)} train, {len(val_images)} val images.")

if __name__ == '__main__':
    base_dataset_dir = '/Users/eabowman/Dropbox/LichenProject/dataset'   # <-- your dataset now (with class folders inside)
    output_dataset_dir = '/Users/eabowman/Dropbox/LichenProject/dataset'         # <-- where you want the organized data

    split_dataset(base_dataset_dir, output_dataset_dir, train_split=0.8)
# Out:
# Class 'Mycoporum_eschweileri': 0 train, 1 val images.
# Class 'Collema_furfuraceum': 10 train, 3 val images.
# Class 'Verrucaria_nigrescens': 9 train, 3 val images.
# Class 'Xanthomendoza_galericulata': 6 train, 2 val images.
# Class 'Arthopyrenia_fallaciosa': 24 train, 6 val images.
# Class 'Aspicilia_filiformis': 0 train, 1 val images.
# Class 'Melaspileella_proximella': 2 train, 1 val images.
# Class 'Enchylium_coccophorum': 1 train, 1 val images.
# Class 'Physcia_stellaris': 28 train, 7 val images.
# Class 'Peccania_subnigra': 0 train, 1 val images.
# Class 'Buellia_erubescens': 47 train, 12 val images.
# Class 'Strigula_smaragdula': 8 train, 2 val images.
# Class 'Xanthoparmelia_australasica': 0 train, 1 val images.
# Class 'Hypogymnia_mollis': 0 train, 1 val images.
# Class 'Graphis_inversa': 2 train, 1 val images.
# Class 'Thelotrema_subtile': 11 train, 3 val images.
# Class 'Porpidia_macrocarpa': 4 train, 1 val images.
# Class 'Staurothele_nemorum': 2 train, 1 val images.
# ...
